# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
#plt.style.use('/Users/summer/desktop/notebook.mplstyle');
# %config InlineBackend.figure_format = 'retina'
colors = ["#2078B5", "#FF7F0F", "#2CA12C", "#D72827", "#9467BE", "#8C574B",
            "#E478C2", "#808080", "#BCBE20", "#17BED0", "#AEC8E9", "#FFBC79", 
            "#98E08B", "#FF9896", "#C6B1D6", "#C59D94", "#F8B7D3", "#C8C8C8", 
           "#DCDC8E", "#9EDAE6"]

# %%
def fast_fourier_transform(t,y):
    '''Return the fast Fourier transform of y.'''
    ŷ = np.fft.fft(y)
    ω = 2*np.pi*np.fft.fftfreq(len(time),time[1]-time[0])
    return ω,ŷ

# %%
I = 4
J = 16
F = 14
c = 10
b = 10
h = 1

dt = 0.0001
#t = np.arange(0,20,dt)

# %%
x = np.random.rand(I)
y = np.random.rand(J,I)
#print("x", x)
#print("y", y)
#print()

newx=[]
time=[0]
for ii in range(I):
    newx.append(x[ii])

#for step in np.arange(0+dt,2,dt):
for step in range(1000000):
    time.append(step)
    dx = np.zeros((I))
    dy = np.zeros((J,I))

    for i in range(I):
        for j in range(J):
            dx[i] = (x[(i-1)%I] * (x[(i+1)%I] - x[(i-2)%I]) - x[i%I] + F - h*c/b*(np.sum([y[jj%J,i] for jj in range(J)])))*dt     
            dy[j,i] = (c*b*y[(j+1)%J,i]*(y[(j-1)%J,i]-y[(j+2)%J,i])-c*y[(j)%J,i]+h*c/b*x[i])*dt

            #x[i]+= dx[i]
            y[j,i]+= dy[j,i]
        x[i]+= dx[i]
            
        newx.append(x[i])
    
#print("final",newx)
x1 = newx[::I]
x2 = newx[1::I]
x3 = newx[2::I]
x4 = newx[3::I]
#print("x1",x1)
#print("x2",x2)
#print("x3",x3)

# %%
fig = plt.figure(figsize=(8,5))
plt.scatter(time,x1, s=1.0, marker='.', c='black')
plt.ylabel(r'$x_1$')
plt.xlabel('time step')
plt.title('1996 Lorenz model\n',fontsize=15)
#plt.xlim(0,2)
#plt.ylim(-8,15)
plt.show()

# %%
fig = plt.figure(figsize=(8,5))
plt.scatter(time[1000::],x1[1000::], s=1.0, marker='.', c='black')
plt.ylabel(r'$x_1$')
plt.xlabel('time step')
plt.title('1996 Lorenz model\n',fontsize=15)
#plt.xlim(18,20)
#plt.ylim(-8,15)
plt.show()

# %%
print(len(x2))
# Out:
# 1000001

# %%
fig = plt.figure(figsize=(8,5))
plt.scatter(x1[950000::],x3[950000::], s=1.0, marker='.', c='black')
plt.ylabel(r'$x_1$')
plt.xlabel('time step')
plt.title('1996 Lorenz model\n',fontsize=15)
#plt.xlim(18,20)
#plt.ylim(-8,15)
plt.show()

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(x2[960000:], x1[960000:], x3[960000:],lw=0.5)
ax.set_xlabel("$x_2$")
ax.set_ylabel("$x_1$")
ax.set_zlabel("$x_3$")
plt.gca().invert_xaxis()
ax.set_title("Lorenz 1996")
plt.show()

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(x2[40000::], x1[40000::], x3[40000::],lw=0.5)
ax.set_xlabel("$x_2$")
ax.set_ylabel("$x_1$")
ax.set_zlabel("$x_3$")
plt.gca().invert_xaxis()
ax.set_title("Lorenz 1996")
plt.show()

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(x2[30000:40000], x1[30000:40000], x3[30000:40000],lw=0.5)
ax.set_xlabel("$x_2$")
ax.set_ylabel("$x_1$")
ax.set_zlabel("$x_3$")
ax.set_title("Lorenz 1996")
plt.show()

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(x2[:3000], x1[:3000], x3[:3000],lw=0.5)
ax.set_xlabel("$x_2$")
ax.set_ylabel("$x_1$")
ax.set_zlabel("$x_3$")
ax.set_title("Lorenz 1996")
plt.show()
